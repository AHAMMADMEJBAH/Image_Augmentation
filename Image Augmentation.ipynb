# %% [markdown]
# ##### Horizontal shift width_shift_range

# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# Load Image Data
image_mejbah = load_img('Mejbah.JPG')
# convert image data to numpy array
data = img_to_array(image_mejbah)
#Expand Dimension  to one sample
samples = expand_dims(data, 0)
#Create image data augmentation generator
data_generator = ImageDataGenerator(width_shift_range=[-200, 200])
#prepare iterator
iterator = data_generator.flow(samples, batch_size = 1)

# %%
for i in range(9):
    #define subplot
    plt.subplot(330 + 1 + i)
    #generate batch of images
    batch = iterator.next()
    #convert to unsigned integers for viewing
    image = batch[0].astype('uint8')
    #plot raw pixel data
    plt.imshow(image)
    
plt.show()

# %%
from numpy import expand_dims
from keras.preprocessing.image import img_to_array, load_img, ImageDataGenerator
import matplotlib.pyplot as plt

#leading image
load_image_mejbah = load_img('Mejbah.JPG')
#Convert to Numpy array
data = img_to_array(load_image_mejbah)
# Expand the dimension to one sample
samples_mejbah = expand_dims(data, 0)

data_generator = ImageDataGenerator(height_shift_range=0.5)
#iterator
iterator = data_generator.flow(samples_mejbah, batch_size = 1)


for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = iterator.next()
    image_mejbah = batch[0].astype('uint8')
    plt.imshow(image_mejbah)

plt.figure(figsize = (8, 10))    
plt.show()

# %% [markdown]
# #### Horizontal and Vertical flip Augmentation

# %%
from numpy import expand_dims
from keras.preprocessing.image import img_to_array, load_img, ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf

load_image_mejbah = load_img('Mejbah.JPG')
array_data = img_to_array(load_image_mejbah)
samples_mejbah = expand_dims(array_data, 0)
Image_data_generator = ImageDataGenerator(horizontal_flip = True)
iterator = Image_data_generator.flow(samples_mejbah, batch_size = 1)

for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = iterator.next()
    image_mejbah = batch[0].astype('uint8')
    plt.imshow(image_mejbah)
    
plt.show()

# %% [markdown]
# #### Random rotation Augmentaion

# %%
from numpy import expand_dims
from keras.preprocessing.image import img_to_array, load_img, ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf

load_image_mejbah = load_img('Mejbah.JPG')
array_data = img_to_array(load_image_mejbah)
samples_mejbah = expand_dims(array_data, 0)
Image_data_generator = ImageDataGenerator(rotation_range = 180)
iterator = Image_data_generator.flow(samples_mejbah, batch_size = 1)

for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = iterator.next()
    image_mejbah = batch[0].astype('uint8')
    plt.imshow(image_mejbah)
plt.show()

# %% [markdown]
# ### Random Brigthness Augmentation

# %%
from numpy import expand_dims
from keras.preprocessing.image import img_to_array, load_img, ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf

load_image_mejbah = load_img('Mejbah.JPG')
array_data = img_to_array(load_image_mejbah)
samples_mejbah = expand_dims(array_data, 0)
Image_data_generator = ImageDataGenerator(brightness_range=[0.2, 1.0])
iterator = Image_data_generator.flow(samples_mejbah, batch_size=1)

for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = iterator.next()
    image_mejbah = batch[0].astype('uint8')
    plt.imshow(image_mejbah)
    
plt.show()

# %% [markdown]
# ### Random Zoom Augmentation

# %%
from numpy import expand_dims
from keras.preprocessing.image import img_to_array, ImageDataGenerator, load_img
import matplotlib.pyplot as plt
import tensorflow as tf

load_image_mejbah = load_img('Mejbah.JPG')
array_data = img_to_array(load_image_mejbah)
samples_mejbah = expand_dims(array_data, 0)
Image_data_generator = ImageDataGenerator(zoom_range=[0.7, 1.8])
iterator = Image_data_generator.flow(samples_mejbah, batch_size=1)

for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = iterator.next()
    image_mejbah = batch[0].astype('uint8')
    plt.imshow(image_mejbah)
    
plt.show()
